# %% [markdown]
# ### 1 Load Dataset

# %%
import csv
import pandas as pd
import numpy as np

fname = 'Rental Data + Other Datasets MERGED ANALYSIS'

# %%
df = pd.read_excel(fname+'.xlsx', parse_dates=['Date'], dayfirst=True)
df = df[df.Region == 'Wellington']
df.head()
# Out:
#            Date      Region  Territorial Authority  \
# 2550 2008-03-01  Wellington     Carterton District
# 2551 2008-03-01  Wellington  Kapiti Coast District
# 2552 2008-03-01  Wellington             Lower Hutt
# 2553 2008-03-01  Wellington     Masterton District
# 2554 2008-03-01  Wellington                Porirua
#
#       Geometric mean rents by region  \
# 2550                             333
# 2551                             333
# 2552                             333
# 2553                             333
# 2554                             333
#
#       Geometric mean rents by territorial authority  \
# 2550                                            197
# 2551                                            284
# 2552                                            283
# 2553                                            213
# 2554                                            302
#
#       Synthetic lower quartile rents by region  \
# 2550                                       249
# 2551                                       249
# 2552                                       249
# 2553                                       249
# 2554                                       249
#
#       Synthetic lower quartile rents by territorial authority  \
# 2550                                                152
# 2551                                                234
# 2552                                                220
# 2553                                                186
# 2554                                                237
#
#       Lodged bonds by region  Lodged bonds by territorial authority  \
# 2550                    1902                                     13
# 2551                    1902                                    131
# 2552                    1902                                    250
# 2553                    1902                                     33
# 2554                    1902                                    104
#
#       Regional GDP             ...              Median Weekly Earnings 20-29  \
# 2550         25074             ...                                     594.5
# 2551         25074             ...                                     594.5
# 2552         25074             ...                                     594.5
# 2553         25074             ...                                     594.5
# 2554         25074             ...                                     594.5
#
#       Number of Residential Building Consents  Student Enrolments by Region  \
# 2550                                     3273                        109010
# 2551                                     3273                        109010
# 2552                                     3273                        109010
# 2553                                     3273                        109010
# 2554                                     3273                        109010
#
#       Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 2550                95355.0            177353.0                     5636.0
# 2551                95355.0            177353.0                     5636.0
# 2552                95355.0            177353.0                     5636.0
# 2553                95355.0            177353.0                     5636.0
# 2554                95355.0            177353.0                     5636.0
#
#       Average Accommodation  CPI  Mortgage Floating rate  \
# 2550                 1140.0  3.4                    10.4
# 2551                 1140.0  3.4                    10.4
# 2552                 1140.0  3.4                    10.4
# 2553                 1140.0  3.4                    10.4
# 2554                 1140.0  3.4                    10.4
#
#       Mortgage 2 year fixed rate
# 2550                         9.5
# 2551                         9.5
# 2552                         9.5
# 2553                         9.5
# 2554                         9.5
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2 Data Transformation

# %%
## Deleting Date of format DateTime as we need int and float objects for regression
import datetime as dt
df['Date']=df['Date'].map(dt.datetime.toordinal)

# Converting categorical values of region and territorial authority to numeric using label encoder
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = df.select_dtypes(include=['object']).apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    df[i] = d[i].transform(df[i].fillna('NA'))
df.head()
# Out:
#         Date  Region  Territorial Authority  Geometric mean rents by region  \
# 2550  733102       0                      0                             333
# 2551  733102       0                      1                             333
# 2552  733102       0                      2                             333
# 2553  733102       0                      3                             333
# 2554  733102       0                      4                             333
#
#       Geometric mean rents by territorial authority  \
# 2550                                            197
# 2551                                            284
# 2552                                            283
# 2553                                            213
# 2554                                            302
#
#       Synthetic lower quartile rents by region  \
# 2550                                       249
# 2551                                       249
# 2552                                       249
# 2553                                       249
# 2554                                       249
#
#       Synthetic lower quartile rents by territorial authority  \
# 2550                                                152
# 2551                                                234
# 2552                                                220
# 2553                                                186
# 2554                                                237
#
#       Lodged bonds by region  Lodged bonds by territorial authority  \
# 2550                    1902                                     13
# 2551                    1902                                    131
# 2552                    1902                                    250
# 2553                    1902                                     33
# 2554                    1902                                    104
#
#       Regional GDP             ...              Median Weekly Earnings 20-29  \
# 2550         25074             ...                                     594.5
# 2551         25074             ...                                     594.5
# 2552         25074             ...                                     594.5
# 2553         25074             ...                                     594.5
# 2554         25074             ...                                     594.5
#
#       Number of Residential Building Consents  Student Enrolments by Region  \
# 2550                                     3273                        109010
# 2551                                     3273                        109010
# 2552                                     3273                        109010
# 2553                                     3273                        109010
# 2554                                     3273                        109010
#
#       Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 2550                95355.0            177353.0                     5636.0
# 2551                95355.0            177353.0                     5636.0
# 2552                95355.0            177353.0                     5636.0
# 2553                95355.0            177353.0                     5636.0
# 2554                95355.0            177353.0                     5636.0
#
#       Average Accommodation  CPI  Mortgage Floating rate  \
# 2550                 1140.0  3.4                    10.4
# 2551                 1140.0  3.4                    10.4
# 2552                 1140.0  3.4                    10.4
# 2553                 1140.0  3.4                    10.4
# 2554                 1140.0  3.4                    10.4
#
#       Mortgage 2 year fixed rate
# 2550                         9.5
# 2551                         9.5
# 2552                         9.5
# 2553                         9.5
# 2554                         9.5
#
# [5 rows x 21 columns]

# %%
df.drop('Synthetic lower quartile rents by territorial authority',axis=1,inplace=True)
df.drop('Synthetic lower quartile rents by region',axis=1,inplace=True)
df.drop('Geometric mean rents by region',axis=1,inplace=True)
df.drop('Lodged bonds by region',axis=1,inplace=True)

# %% [markdown]
# ### 3 Model Selection

# %%
## Choosing Geometric mean as target as less affected by outliers compared to arithemtic mean 
df['target'] = df['Geometric mean rents by territorial authority']
df.drop('Geometric mean rents by territorial authority',axis=1,inplace=True)

features = df[df.columns.difference(df['target'])]
labels = df['target']
features.drop('target',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
print(features.shape,labels.shape)
# Out:
# (335, 16) (335,)

# %% [markdown]
# ### 4 Feature Selection

# %%
from feature_selector import FeatureSelector
fs=FeatureSelector(data=features, labels=labels)
fs.identify_zero_importance(task = 'regression', 
                            eval_metric = 'auc', 
                            n_iterations = 30, 
                             early_stopping = True)

# list of zero importance features
fs.ops['zero_importance']
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
# 4 features with zero importance after one-hot encoding.
# ['Population Estimate 15-39',
#  'Region',
#  'Regional GDP',
#  'Student Enrolments by Region']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 11 features required for 0.99 of cumulative importance

# %%
fs.feature_importances
# Out:
#                                     feature  importance  \
# 0     Lodged bonds by territorial authority    3.166667
# 1                        Approved Work Visa    1.933333
# 2                     Average Accommodation    0.900000
# 3                     Approved Student Visa    0.866667
# 4                                      Date    0.833333
# 5                     Territorial Authority    0.833333
# 6              Median Weekly Earnings 20-29    0.266667
# 7                 Average Student Allowance    0.200000
# 8                                       CPI    0.100000
# 9   Number of Residential Building Consents    0.100000
# 10               Mortgage 2 year fixed rate    0.066667
# 11                   Mortgage Floating rate    0.033333
# 12                Population Estimate 15-39    0.000000
# 13                                   Region    0.000000
# 14                             Regional GDP    0.000000
# 15             Student Enrolments by Region    0.000000
#
#     normalized_importance  cumulative_importance
# 0                0.340502               0.340502
# 1                0.207885               0.548387
# 2                0.096774               0.645161
# 3                0.093190               0.738351
# 4                0.089606               0.827957
# 5                0.089606               0.917563
# 6                0.028674               0.946237
# 7                0.021505               0.967742
# 8                0.010753               0.978495
# 9                0.010753               0.989247
# 10               0.007168               0.996416
# 11               0.003584               1.000000
# 12               0.000000               1.000000
# 13               0.000000               1.000000
# 14               0.000000               1.000000
# 15               0.000000               1.000000

# %%
features = fs.remove(methods='all',keep_one_hot=False)
# Out:
# ['zero_importance'] methods have been run
#
# Removed 4 features including one-hot features.

# %%
features.head()
# Out:
#       Approved Student Visa  Approved Work Visa  Average Accommodation  \
# 2550                95355.0            177353.0                 1140.0
# 2551                95355.0            177353.0                 1140.0
# 2552                95355.0            177353.0                 1140.0
# 2553                95355.0            177353.0                 1140.0
# 2554                95355.0            177353.0                 1140.0
#
#       Average Student Allowance  CPI    Date  \
# 2550                     5636.0  3.4  733102
# 2551                     5636.0  3.4  733102
# 2552                     5636.0  3.4  733102
# 2553                     5636.0  3.4  733102
# 2554                     5636.0  3.4  733102
#
#       Lodged bonds by territorial authority  Median Weekly Earnings 20-29  \
# 2550                                     13                         594.5
# 2551                                    131                         594.5
# 2552                                    250                         594.5
# 2553                                     33                         594.5
# 2554                                    104                         594.5
#
#       Mortgage 2 year fixed rate  Mortgage Floating rate  \
# 2550                         9.5                    10.4
# 2551                         9.5                    10.4
# 2552                         9.5                    10.4
# 2553                         9.5                    10.4
# 2554                         9.5                    10.4
#
#       Number of Residential Building Consents  Territorial Authority
# 2550                                     3273                      0
# 2551                                     3273                      1
# 2552                                     3273                      2
# 2553                                     3273                      3
# 2554                                     3273                      4

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### 4.2 Gradient Boosting Regression Model

# %%
from sklearn.cross_validation import train_test_split
from datetime import datetime

final_vars = list(features) + ['target']
df1 = df[final_vars]
df1.head()

df['Date']=df['Date'].map(dt.datetime.fromordinal)
# train, test = train_test_split(df1, test_size = 0.4)
train = df[df['Date'].dt.year <= 2017]
test = df[df['Date'].dt.year > 2017]

train['Date']=train['Date'].map(dt.datetime.toordinal)
test['Date']=test['Date'].map(dt.datetime.toordinal)

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

X_train  = train[list(features)]
y_train  = train['target']
X_test = test[list(features)]
y_test  = test['target']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### 4.2.1 Gradient Boosting - Hyperparameter Tuning

# %%
from sklearn import cross_validation, metrics   
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

gb = GradientBoostingRegressor()

gf_tune = GridSearchCV(estimator = gb, param_grid = grid, cv = 2, verbose=2, n_jobs = -1)
gf_tune.fit(X_train, y_train)

print(gf_tune.best_params_)
# Out:
# Fitting 2 folds for each of 360 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:    7.1s
# {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 500}
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   12.5s finished

# %% [markdown]
# #### 4.2.2 Model

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.learning_curve import learning_curve
import matplotlib.pyplot as plt
import time
start_time = time.time()

model = GradientBoostingRegressor(**gf_tune.best_params_)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
model_mse = mean_squared_error(y_pred, y_test)
model_rmse = np.sqrt(model_mse)
print('Gradient Boosting R squared: %.4f' % model.score(X_test, y_test))
print('Gradient Boosting RMSE: %.4f' % model_rmse)
# Out:
# Gradient Boosting R squared: 0.7050
# Gradient Boosting RMSE: 30.6459

# %% [markdown]
# #### 4.2.3 Evaluating Feature Importance

# %%
feature_labels = list(features)
feature_importance = model.feature_importances_

feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.asarray(feature_labels)[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

feature_indexes_by_importance = feature_importance.argsort()
for index in reversed(feature_indexes_by_importance):
    print('{}-{:.2f}%'.format(feature_labels[index], (feature_importance[index])))
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Lodged bonds by territorial authority-100.00%
# Territorial Authority-58.88%
# Median Weekly Earnings 20-29-14.56%
# Number of Residential Building Consents-14.06%
# CPI-10.18%
# Average Accommodation-9.35%
# Approved Student Visa-9.28%
# Average Student Allowance-8.82%
# Date-8.32%
# Approved Work Visa-6.48%
# Mortgage Floating rate-5.72%
# Mortgage 2 year fixed rate-5.59%
# --- 0.25166821479797363 seconds ---

# %%
# dates = df[df['Date'].dt.year > 2017]
# dates = dates['Date']
# dates = dates.reset_index(drop=True)

# y_pred = pd.Series(y_pred.tolist())
# pred_data = pd.concat([dates, y_pred], axis=1)
# pred_data.to_csv('PREDICTION/pred_data.csv')

# %% [markdown]
# #### 4.2.4 Learning Curve

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.
        
    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(model, "Learning curve", X_train, y_train, cv=10, n_jobs=3) 
plt.show()
