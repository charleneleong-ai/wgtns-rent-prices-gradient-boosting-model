# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# ### 1.1 Load Dataset

# %%
import csv
import pandas as pd
import numpy as np

fname = 'Rental Data + Other Datasets MERGED ANALYSIS'

# %%
df = pd.read_excel(fname+'.xlsx', parse_dates=['Date'], dayfirst=True)
df.head()
# Out:
#         Date    Region Territorial Authority  Geometric mean rents by region  \
# 0 2008-03-01  Auckland              Auckland                             347
# 1 2008-03-01  Auckland     Franklin District                             347
# 2 2008-03-01  Auckland               Manukau                             347
# 3 2008-03-01  Auckland           North Shore                             347
# 4 2008-03-01  Auckland     Papakura District                             347
#
#    Geometric mean rents by territorial authority  \
# 0                                            356
# 1                                            294
# 2                                            345
# 3                                            344
# 4                                            323
#
#    Synthetic lower quartile rents by region  \
# 0                                       273
# 1                                       273
# 2                                       273
# 3                                       273
# 4                                       273
#
#    Synthetic lower quartile rents by territorial authority  \
# 0                                                277
# 1                                                250
# 2                                                288
# 3                                                253
# 4                                                265
#
#    Lodged bonds by region  Lodged bonds by territorial authority  \
# 0                    4950                                   2477
# 1                    4950                                    136
# 2                    4950                                    722
# 3                    4950                                    792
# 4                    4950                                    118
#
#    Regional GDP             ...              Median Weekly Earnings 20-29  \
# 0         64644             ...                                     594.5
# 1         64644             ...                                     594.5
# 2         64644             ...                                     594.5
# 3         64644             ...                                     594.5
# 4         64644             ...                                     594.5
#
#    Number of Residential Building Consents  Student Enrolments by Region  \
# 0                                     7999                         90620
# 1                                     7999                         90620
# 2                                     7999                         90620
# 3                                     7999                         90620
# 4                                     7999                         90620
#
#    Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 0                95355.0            177353.0                     5636.0
# 1                95355.0            177353.0                     5636.0
# 2                95355.0            177353.0                     5636.0
# 3                95355.0            177353.0                     5636.0
# 4                95355.0            177353.0                     5636.0
#
#    Average Accommodation  CPI  Mortgage Floating rate  \
# 0                 1140.0  3.4                    10.4
# 1                 1140.0  3.4                    10.4
# 2                 1140.0  3.4                    10.4
# 3                 1140.0  3.4                    10.4
# 4                 1140.0  3.4                    10.4
#
#    Mortgage 2 year fixed rate
# 0                         9.5
# 1                         9.5
# 2                         9.5
# 3                         9.5
# 4                         9.5
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3010 entries, 0 to 3009
# Data columns (total 21 columns):
# Date                                                       3010 non-null datetime64[ns]
# Region                                                     3010 non-null object
# Territorial Authority                                      3010 non-null object
# Geometric mean rents by region                             3010 non-null int64
# Geometric mean rents by territorial authority              3010 non-null int64
# Synthetic lower quartile rents by region                   3010 non-null int64
# Synthetic lower quartile rents by territorial authority    3010 non-null int64
# Lodged bonds by region                                     3010 non-null int64
# Lodged bonds by territorial authority                      3010 non-null int64
# Regional GDP                                               3010 non-null int64
# Population Estimate 15-39                                  3010 non-null float64
# Median Weekly Earnings 20-29                               3010 non-null float64
# Number of Residential Building Consents                    3010 non-null int64
# Student Enrolments by Region                               3010 non-null int64
# Approved Student Visa                                      3010 non-null float64
# Approved Work Visa                                         3010 non-null float64
# Average Student Allowance                                  3010 non-null float64
# Average Accommodation                                      3010 non-null float64
# CPI                                                        3010 non-null float64
# Mortgage Floating rate                                     3010 non-null float64
# Mortgage 2 year fixed rate                                 3010 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9), object(2)
# memory usage: 493.9+ KB

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### 2.1 Descriptive Stats

# %%
df.describe()
# Out:
#        Geometric mean rents by region  \
# count                     3010.000000
# mean                       300.047841
# std                         65.742554
# min                        169.000000
# 25%                        257.000000
# 50%                        283.000000
# 75%                        343.000000
# max                        519.000000
#
#        Geometric mean rents by territorial authority  \
# count                                    3010.000000
# mean                                      272.603322
# std                                        78.470499
# min                                       129.000000
# 25%                                       215.000000
# 50%                                       262.000000
# 75%                                       314.000000
# max                                       580.000000
#
#        Synthetic lower quartile rents by region  \
# count                               3010.000000
# mean                                 234.540199
# std                                   49.335962
# min                                  130.000000
# 25%                                  203.000000
# 50%                                  226.000000
# 75%                                  264.000000
# max                                  407.000000
#
#        Synthetic lower quartile rents by territorial authority  \
# count                                        3010.000000
# mean                                          222.547508
# std                                            61.721848
# min                                            80.000000
# 25%                                           178.000000
# 50%                                           215.000000
# 75%                                           257.000000
# max                                           468.000000
#
#        Lodged bonds by region  Lodged bonds by territorial authority  \
# count             3010.000000                            3010.000000
# mean              1401.881063                             201.816611
# std               1384.393104                             378.576388
# min                 41.000000                               5.000000
# 25%                453.000000                              30.000000
# 50%               1051.000000                              83.000000
# 75%               1706.000000                             179.750000
# max               7091.000000                            3567.000000
#
#        Regional GDP  Population Estimate 15-39  Median Weekly Earnings 20-29  \
# count   3010.000000               3.010000e+03                   3010.000000
# mean   21599.526246               1.514219e+06                    613.333785
# std    21893.716565               7.695526e+04                     43.597274
# min     1246.000000               1.452448e+06                    544.500000
# 25%     7615.000000               1.457983e+06                    578.000000
# 50%    13084.000000               1.462965e+06                    603.124921
# 75%    28203.000000               1.569095e+06                    649.000000
# max    96442.000000               1.695545e+06                    734.000000
#
#        Number of Residential Building Consents  Student Enrolments by Region  \
# count                              3010.000000                   3010.000000
# mean                               3262.681395                  34624.227907
# std                                2858.347053                  35907.105199
# min                                 157.000000                      0.000000
# 25%                                1100.750000                   7253.000000
# 50%                                2612.000000                  22070.000000
# 75%                                4189.000000                  42358.000000
# max                               15050.000000                 113305.000000
#
#        Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# count            3010.000000         3010.000000                3010.000000
# mean            95361.225498       188205.631645                5958.175997
# std              9080.168747        29503.682319                 190.146321
# min             76790.000000       151537.000000                5636.000000
# 25%             88870.500000       162524.500000                5849.500000
# 50%             94559.500000       174728.500000                5929.500000
# 75%            104129.750000       222224.500000                6040.500000
# max            106709.000000       235146.500000                6399.000000
#
#        Average Accommodation          CPI  Mortgage Floating rate  \
# count            3010.000000  3010.000000             3010.000000
# mean             1235.160631     1.845382                6.382990
# std                66.762942     1.357566                1.216335
# min              1140.000000     0.100000                5.600000
# 25%              1196.000000     0.900000                5.800000
# 50%              1213.500000     1.600000                5.900000
# 75%              1274.000000     2.000000                6.300000
# max              1393.000000     5.300000               10.700000
#
#        Mortgage 2 year fixed rate
# count                 3010.000000
# mean                     6.121462
# std                      1.061974
# min                      5.000000
# 25%                      5.200000
# 50%                      6.000000
# 75%                      6.600000
# max                      9.500000

# %% [markdown]
# ### 2.2 Histogram Plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### 2.3 Correlation Matrix

# %%
import seaborn as sns

corr = df.corr(method='pearson')
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
corr["Geometric mean rents by territorial authority"].sort_values(ascending=False)
# Out:
# Geometric mean rents by territorial authority              1.000000
# Synthetic lower quartile rents by territorial authority    0.984013
# Synthetic lower quartile rents by region                   0.771979
# Geometric mean rents by region                             0.768487
# Regional GDP                                               0.660302
# Number of Residential Building Consents                    0.610616
# Lodged bonds by region                                     0.553832
# Student Enrolments by Region                               0.507180
# Lodged bonds by territorial authority                      0.472036
# Average Student Allowance                                  0.354468
# Average Accommodation                                      0.351793
# Population Estimate 15-39                                  0.347084
# Approved Work Visa                                         0.337976
# Median Weekly Earnings 20-29                               0.322854
# Approved Student Visa                                      0.239797
# Mortgage Floating rate                                    -0.177434
# CPI                                                       -0.187126
# Mortgage 2 year fixed rate                                -0.280203
# Name: Geometric mean rents by territorial authority, dtype: float64

# %% [markdown]
# ### 2.4 Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
attributes = ["Geometric mean rents by territorial authority",
#               "Synthetic lower quartile rents by territorial authority", 
#               "Synthetic lower quartile rents by region", 
#               "Geometric mean rents by region", 
              "Regional GDP",
             "Number of Residential Building Consents",
#              "Lodged bonds by region",
              "Student Enrolments by Region",
              "Lodged bonds by territorial authority"
#               "Average Student Allowance",
#               "Average Accommodation",
#               "Population Estimate 15-39",
#               "Approved Work Visa",
#               "Median Weekly Earnings"
             ]
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Regional GDP", alpha=0.5)

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Student Enrolments by Region", alpha=0.5)

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Lodged bonds by territorial authority", alpha=0.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

#order by max
sns.catplot(x="Geometric mean rents by region", y="Region", 
            order=['Auckland','Wellington','Otago', 'Bay of Plenty','Canterbury',
                   'Tasman','Nelson','Hawke\'s Bay','Northland','Waikato'],
            jitter=False, data=df);

# %%
region_df = df[df['Date'].dt.year >= 2016]
sns.catplot(x="Geometric mean rents by territorial authority", y="Region", kind="violin", 
            order=['Auckland','Wellington', 'Otago', 'Canterbury','Bay of Plenty'],
            data=region_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 3. Data Preparation - Model and Feature Selection

# %% [markdown]
# ### 3.1 Data Transformation

# %%
## Deleting Date of format DateTime as we need int and float objects for regression
import datetime as dt
df['Date']=df['Date'].map(dt.datetime.toordinal)

# Converting categorical values of region and territorial authority to numeric using label encoder
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = df.select_dtypes(include=['object']).apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    df[i] = d[i].transform(df[i].fillna('NA'))
df.head()
# Out:
#      Date  Region  Territorial Authority  Geometric mean rents by region  \
# 0  733102       0                      1                             347
# 1  733102       0                     10                             347
# 2  733102       0                     27                             347
# 3  733102       0                     34                             347
# 4  733102       0                     38                             347
#
#    Geometric mean rents by territorial authority  \
# 0                                            356
# 1                                            294
# 2                                            345
# 3                                            344
# 4                                            323
#
#    Synthetic lower quartile rents by region  \
# 0                                       273
# 1                                       273
# 2                                       273
# 3                                       273
# 4                                       273
#
#    Synthetic lower quartile rents by territorial authority  \
# 0                                                277
# 1                                                250
# 2                                                288
# 3                                                253
# 4                                                265
#
#    Lodged bonds by region  Lodged bonds by territorial authority  \
# 0                    4950                                   2477
# 1                    4950                                    136
# 2                    4950                                    722
# 3                    4950                                    792
# 4                    4950                                    118
#
#    Regional GDP             ...              Median Weekly Earnings 20-29  \
# 0         64644             ...                                     594.5
# 1         64644             ...                                     594.5
# 2         64644             ...                                     594.5
# 3         64644             ...                                     594.5
# 4         64644             ...                                     594.5
#
#    Number of Residential Building Consents  Student Enrolments by Region  \
# 0                                     7999                         90620
# 1                                     7999                         90620
# 2                                     7999                         90620
# 3                                     7999                         90620
# 4                                     7999                         90620
#
#    Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 0                95355.0            177353.0                     5636.0
# 1                95355.0            177353.0                     5636.0
# 2                95355.0            177353.0                     5636.0
# 3                95355.0            177353.0                     5636.0
# 4                95355.0            177353.0                     5636.0
#
#    Average Accommodation  CPI  Mortgage Floating rate  \
# 0                 1140.0  3.4                    10.4
# 1                 1140.0  3.4                    10.4
# 2                 1140.0  3.4                    10.4
# 3                 1140.0  3.4                    10.4
# 4                 1140.0  3.4                    10.4
#
#    Mortgage 2 year fixed rate
# 0                         9.5
# 1                         9.5
# 2                         9.5
# 3                         9.5
# 4                         9.5
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 3.2 Eliminating Multi-collinearity

# %%
from feature_selector import FeatureSelector
fs=FeatureSelector(df)
fs.identify_collinear(correlation_threshold = 0.90)
fs.plot_collinear()
# Out:
# No labels provided. Feature importance based methods are not available.
# 6 features with a correlation magnitude greater than 0.90.

# %%
# list of collinear features to remove
collinear_features = fs.ops['collinear']

# dataframe of collinear features
fs.record_collinear
# Out:
#                                         drop_feature  \
# 0           Synthetic lower quartile rents by region
# 1  Synthetic lower quartile rents by territorial ...
# 2                                       Regional GDP
# 3                                 Approved Work Visa
# 4                          Average Student Allowance
# 5                              Average Accommodation
# 6                              Average Accommodation
#
#                                     corr_feature  corr_value
# 0                 Geometric mean rents by region    0.984558
# 1  Geometric mean rents by territorial authority    0.984013
# 2                         Lodged bonds by region    0.921240
# 3                      Population Estimate 15-39    0.941148
# 4                                           Date    0.936628
# 5                      Population Estimate 15-39    0.952357
# 6                      Average Student Allowance    0.976617

# %%
df.drop('Synthetic lower quartile rents by territorial authority',axis=1,inplace=True)
df.drop('Synthetic lower quartile rents by region',axis=1,inplace=True)
df.drop('Geometric mean rents by region',axis=1,inplace=True)
df.drop('Lodged bonds by region',axis=1,inplace=True)

df.drop('Approved Work Visa',axis=1,inplace=True)
df.drop('Average Student Allowance',axis=1,inplace=True)
df.drop('Average Accommodation',axis=1,inplace=True)

fs=FeatureSelector(df)
fs.identify_collinear(correlation_threshold = 0.90)

# list of collinear features to remove
collinear_features = fs.ops['collinear']

# dataframe of collinear features
fs.record_collinear
fs.plot_collinear(plot_all = True)
# Out:
# No labels provided. Feature importance based methods are not available.
# 0 features with a correlation magnitude greater than 0.90.

# %% [markdown]
# ### 3.2 Model Selection

# %%
## Choosing Geometric mean as target as less affected by outliers compared to arithemtic mean 
df['target'] = df['Geometric mean rents by territorial authority']
df.drop('Geometric mean rents by territorial authority',axis=1,inplace=True)

features = df[df.columns.difference(df['target'])]
labels = df['target']
features.drop('target',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
print(features.shape, ' ',labels.shape)
# Out:
# (3010, 13)   (3010,)

# %% [markdown]
# ### 3.3 Feature Selection

# %%
fs=FeatureSelector(data=features, labels=labels)
fs.identify_zero_importance(task = 'regression', 
                            eval_metric = 'auc', 
                            n_iterations = 30, 
                             early_stopping = True)

# list of zero importance features
fs.ops['zero_importance']
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
# 3 features with zero importance after one-hot encoding.
# ['Mortgage 2 year fixed rate',
#  'Mortgage Floating rate',
#  'Population Estimate 15-39']

# %%
# fs.identify_low_importance(cumulative_importance = 0.99)
# fs.ops['low_importance']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 9 features required for 0.99 of cumulative importance

# %%
fs.feature_importances
# Out:
#                                     feature  importance  \
# 0                     Territorial Authority    8.533333
# 1     Lodged bonds by territorial authority    6.500000
# 2                              Regional GDP    4.766667
# 3                                      Date    3.766667
# 4                                    Region    2.466667
# 5              Student Enrolments by Region    2.233333
# 6                     Approved Student Visa    0.700000
# 7   Number of Residential Building Consents    0.566667
# 8                                       CPI    0.300000
# 9              Median Weekly Earnings 20-29    0.166667
# 10               Mortgage 2 year fixed rate    0.000000
# 11                   Mortgage Floating rate    0.000000
# 12                Population Estimate 15-39    0.000000
#
#     normalized_importance  cumulative_importance
# 0                0.284444               0.284444
# 1                0.216667               0.501111
# 2                0.158889               0.660000
# 3                0.125556               0.785556
# 4                0.082222               0.867778
# 5                0.074444               0.942222
# 6                0.023333               0.965556
# 7                0.018889               0.984444
# 8                0.010000               0.994444
# 9                0.005556               1.000000
# 10               0.000000               1.000000
# 11               0.000000               1.000000
# 12               0.000000               1.000000

# %%
features = fs.remove(methods='all',keep_one_hot=False)
# Out:
# ['zero_importance'] methods have been run
#
# Removed 3 features including one-hot features.

# %%
features.head()
# Out:
#    Approved Student Visa  CPI    Date  Lodged bonds by territorial authority  \
# 0                95355.0  3.4  733102                                   2477
# 1                95355.0  3.4  733102                                    136
# 2                95355.0  3.4  733102                                    722
# 3                95355.0  3.4  733102                                    792
# 4                95355.0  3.4  733102                                    118
#
#    Median Weekly Earnings 20-29  Number of Residential Building Consents  \
# 0                         594.5                                     7999
# 1                         594.5                                     7999
# 2                         594.5                                     7999
# 3                         594.5                                     7999
# 4                         594.5                                     7999
#
#    Region  Regional GDP  Student Enrolments by Region  Territorial Authority
# 0       0         64644                         90620                      1
# 1       0         64644                         90620                     10
# 2       0         64644                         90620                     27
# 3       0         64644                         90620                     34
# 4       0         64644                         90620                     38

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### 4.1 Before and After Collinearity

# %%
# df_bf_collinear = pd.read_excel(fname+'.xlsx', parse_dates=['Date'], dayfirst=True)

# #remove other target variables
# df_bf_collinear['target'] = df_bf_collinear['Geometric mean rents by territorial authority']
# df_bf_collinear.drop('Geometric mean rents by territorial authority',axis=1,inplace=True)
# df_bf_collinear.drop('Synthetic lower quartile rents by territorial authority',axis=1,inplace=True)
# df_bf_collinear.drop('Synthetic lower quartile rents by region',axis=1,inplace=True)
# df_bf_collinear.drop('Geometric mean rents by region',axis=1,inplace=True)

# #remove highly correlated vars 
# df_bf_collinear.drop('Lodged bonds by region',axis=1,inplace=True)
# df_bf_collinear.drop('Approved Work Visa',axis=1,inplace=True)
# df_bf_collinear.drop('Average Student Allowance',axis=1,inplace=True)
# df_bf_collinear.drop('Average Accommodation',axis=1,inplace=True)

# #
# df_bf_collinear['Date']=df_bf_collinear['Date'].map(dt.datetime.toordinal)
# fit = df_bf_collinear.select_dtypes(include=['object']).apply(lambda x: d[x.name].fit_transform(x))
# for i in list(d.keys()):
#     df_bf_collinear[i] = d[i].transform(df_bf_collinear[i].fillna('NA'))
# df_bf_collinear.head()

# features = df_bf_collinear[df_bf_collinear.columns.difference(df_bf_collinear['target'])]
# features.drop('target',axis=1,inplace=True)
# df_bf_collinear.head()

# %% [markdown]
# ### 4.2 Gradient Boosting Regression Model

# %%
from sklearn.cross_validation import train_test_split

final_vars = list(features) + ['target']
df1 = df[final_vars]
df1.head()

df['Date']=df['Date'].map(dt.datetime.fromordinal)
# train, test = train_test_split(df1, test_size = 0.4)
train = df[df['Date'].dt.year <= 2016]
test = df[df['Date'].dt.year > 2016]

train['Date']=train['Date'].map(dt.datetime.toordinal)
test['Date']=test['Date'].map(dt.datetime.toordinal)

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

X_train  = train[list(features)]
y_train  = train['target']
X_test = test[list(features)]
y_test  = test['target']

# %% [markdown]
# #### 4.2.1 Gradient Boosting - Hyperparameter Tuning

# %%
from sklearn import cross_validation, metrics   
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

gb = GradientBoostingRegressor()

gf_tune = GridSearchCV(estimator = gb, param_grid = grid, cv = 2, verbose=2, n_jobs = -1)
gf_tune.fit(X_train, y_train)

print(gf_tune.best_params_)
# Out:
# Fitting 2 folds for each of 360 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   52.4s finished
# {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 500}

# %% [markdown]
# #### 4.2.2 Model

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.learning_curve import learning_curve
import time
start_time = time.time()

model = GradientBoostingRegressor(**gf_tune.best_params_)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
model_mse = mean_squared_error(y_pred, y_test)
model_rmse = np.sqrt(model_mse)
print('Gradient Boosting R squared: %.4f' % model.score(X_test, y_test))
print('Gradient Boosting RMSE: %.4f' % model_rmse)
# Out:
# Gradient Boosting R squared: 0.9440
# Gradient Boosting RMSE: 18.8181

# %% [markdown]
# #### 4.2.3 Evaluating Feature Importance

# %%
feature_labels = list(features)
feature_importance = model.feature_importances_

feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.asarray(feature_labels)[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

feature_indexes_by_importance = feature_importance.argsort()
for index in reversed(feature_indexes_by_importance):
    print('{}-{:.2f}%'.format(feature_labels[index], (feature_importance[index])))
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Territorial Authority-100.00%
# Lodged bonds by territorial authority-69.92%
# Regional GDP-36.79%
# Number of Residential Building Consents-32.48%
# Student Enrolments by Region-29.29%
# Date-18.08%
# Region-11.48%
# Approved Student Visa-11.25%
# Median Weekly Earnings 20-29-8.45%
# CPI-3.75%
# --- 0.5344192981719971 seconds ---

# %% [markdown]
# #### 4.2.4 Learning Curve

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.
        
    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(model, "Learning curve", X_train, y_train, cv=10, n_jobs=3) 
plt.show()
