# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# ### 1.1 Load Dataset

# %%
import csv
import pandas as pd
import numpy as np

fname = 'Rental Data + Other Datasets MERGED ANALYSIS'

# %%
df = pd.read_excel(fname+'.xlsx', parse_dates=['Date'], dayfirst=True)
df = df[df.Region == 'Auckland']
df.head()
# Out:
#         Date    Region Territorial Authority  Geometric mean rents by region  \
# 0 2008-03-01  Auckland              Auckland                             347
# 1 2008-03-01  Auckland     Franklin District                             347
# 2 2008-03-01  Auckland               Manukau                             347
# 3 2008-03-01  Auckland           North Shore                             347
# 4 2008-03-01  Auckland     Papakura District                             347
#
#    Geometric mean rents by territorial authority  \
# 0                                            356
# 1                                            294
# 2                                            345
# 3                                            344
# 4                                            323
#
#    Synthetic lower quartile rents by region  \
# 0                                       273
# 1                                       273
# 2                                       273
# 3                                       273
# 4                                       273
#
#    Synthetic lower quartile rents by territorial authority  \
# 0                                                277
# 1                                                250
# 2                                                288
# 3                                                253
# 4                                                265
#
#    Lodged bonds by region  Lodged bonds by territorial authority  \
# 0                    4950                                   2477
# 1                    4950                                    136
# 2                    4950                                    722
# 3                    4950                                    792
# 4                    4950                                    118
#
#    Regional GDP             ...              Median Weekly Earnings 20-29  \
# 0         64644             ...                                     594.5
# 1         64644             ...                                     594.5
# 2         64644             ...                                     594.5
# 3         64644             ...                                     594.5
# 4         64644             ...                                     594.5
#
#    Number of Residential Building Consents  Student Enrolments by Region  \
# 0                                     7999                         90620
# 1                                     7999                         90620
# 2                                     7999                         90620
# 3                                     7999                         90620
# 4                                     7999                         90620
#
#    Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 0                95355.0            177353.0                     5636.0
# 1                95355.0            177353.0                     5636.0
# 2                95355.0            177353.0                     5636.0
# 3                95355.0            177353.0                     5636.0
# 4                95355.0            177353.0                     5636.0
#
#    Average Accommodation  CPI  Mortgage Floating rate  \
# 0                 1140.0  3.4                    10.4
# 1                 1140.0  3.4                    10.4
# 2                 1140.0  3.4                    10.4
# 3                 1140.0  3.4                    10.4
# 4                 1140.0  3.4                    10.4
#
#    Mortgage 2 year fixed rate
# 0                         9.5
# 1                         9.5
# 2                         9.5
# 3                         9.5
# 4                         9.5
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 293
# Data columns (total 21 columns):
# Date                                                       294 non-null datetime64[ns]
# Region                                                     294 non-null object
# Territorial Authority                                      294 non-null object
# Geometric mean rents by region                             294 non-null int64
# Geometric mean rents by territorial authority              294 non-null int64
# Synthetic lower quartile rents by region                   294 non-null int64
# Synthetic lower quartile rents by territorial authority    294 non-null int64
# Lodged bonds by region                                     294 non-null int64
# Lodged bonds by territorial authority                      294 non-null int64
# Regional GDP                                               294 non-null int64
# Population Estimate 15-39                                  294 non-null float64
# Median Weekly Earnings 20-29                               294 non-null float64
# Number of Residential Building Consents                    294 non-null int64
# Student Enrolments by Region                               294 non-null int64
# Approved Student Visa                                      294 non-null float64
# Approved Work Visa                                         294 non-null float64
# Average Student Allowance                                  294 non-null float64
# Average Accommodation                                      294 non-null float64
# CPI                                                        294 non-null float64
# Mortgage Floating rate                                     294 non-null float64
# Mortgage 2 year fixed rate                                 294 non-null float64
# dtypes: datetime64[ns](1), float64(9), int64(9), object(2)
# memory usage: 50.5+ KB

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### 2.1 Descriptive Stats

# %%
df.describe()
# Out:
#        Geometric mean rents by region  \
# count                      294.000000
# mean                       423.571429
# std                         52.965183
# min                        347.000000
# 25%                        375.000000
# 50%                        416.500000
# 75%                        470.000000
# max                        519.000000
#
#        Geometric mean rents by territorial authority  \
# count                                     294.000000
# mean                                      409.972789
# std                                        64.405228
# min                                       294.000000
# 25%                                       357.500000
# 50%                                       400.500000
# 75%                                       463.000000
# max                                       580.000000
#
#        Synthetic lower quartile rents by region  \
# count                                294.000000
# mean                                 333.523810
# std                                   40.711896
# min                                  273.000000
# 25%                                  293.000000
# 50%                                  328.000000
# 75%                                  370.000000
# max                                  407.000000
#
#        Synthetic lower quartile rents by territorial authority  \
# count                                         294.000000
# mean                                          331.744898
# std                                            49.423912
# min                                           242.000000
# 25%                                           290.000000
# 50%                                           325.000000
# 75%                                           372.750000
# max                                           468.000000
#
#        Lodged bonds by region  Lodged bonds by territorial authority  \
# count              294.000000                             294.000000
# mean              4915.571429                             702.224490
# std               1034.751742                             728.481771
# min               2906.000000                              59.000000
# 25%               4376.000000                             181.250000
# 50%               4703.500000                             499.500000
# 75%               5523.000000                             817.250000
# max               7091.000000                            3567.000000
#
#        Regional GDP  Population Estimate 15-39  Median Weekly Earnings 20-29  \
# count    294.000000               2.940000e+02                    294.000000
# mean   80542.690476               1.514341e+06                    613.420180
# std     9416.516962               7.715857e+04                     43.620218
# min    64644.000000               1.452448e+06                    544.500000
# 25%    72399.000000               1.457983e+06                    578.000000
# 50%    80542.500000               1.463242e+06                    604.670735
# 75%    88686.000000               1.569095e+06                    649.000000
# max    96442.000000               1.695545e+06                    734.000000
#
#        Number of Residential Building Consents  Student Enrolments by Region  \
# count                               294.000000                    294.000000
# mean                               9089.619048                  95137.285714
# std                                2858.274499                   1361.417102
# min                                5476.000000                  90620.000000
# 25%                                6460.000000                  94565.000000
# 50%                                8323.000000                  95291.500000
# 75%                               11456.000000                  95446.000000
# max                               15050.000000                  98460.000000
#
#        Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# count             294.000000          294.000000                 294.000000
# mean            95368.077381       188255.476190                5958.642857
# std              9093.796183        29550.155035                 190.508870
# min             76790.000000       151537.000000                5636.000000
# 25%             88870.500000       162524.500000                5849.500000
# 50%             94758.375000       176040.750000                5932.750000
# 75%            104129.750000       222224.500000                6040.500000
# max            106709.000000       235146.500000                6399.000000
#
#        Average Accommodation         CPI  Mortgage Floating rate  \
# count             294.000000  294.000000              294.000000
# mean             1235.285714    1.842857                6.380952
# std                66.922240    1.357221                1.215926
# min              1140.000000    0.100000                5.600000
# 25%              1196.000000    0.900000                5.800000
# 50%              1213.750000    1.600000                5.900000
# 75%              1274.000000    2.000000                6.300000
# max              1393.000000    5.300000               10.700000
#
#        Mortgage 2 year fixed rate
# count                  294.000000
# mean                     6.119048
# std                      1.062185
# min                      5.000000
# 25%                      5.200000
# 50%                      5.950000
# 75%                      6.600000
# max                      9.500000

# %% [markdown]
# ### 2.2 Histogram Plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### 2.3 Correlation Matrix

# %%
import seaborn as sns

corr = df.corr(method='pearson')
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
corr["Geometric mean rents by territorial authority"].sort_values(ascending=False)
# Out:
# Geometric mean rents by territorial authority              1.000000
# Synthetic lower quartile rents by territorial authority    0.975066
# Geometric mean rents by region                             0.872224
# Synthetic lower quartile rents by region                   0.870099
# Regional GDP                                               0.859207
# Approved Work Visa                                         0.818492
# Average Student Allowance                                  0.811725
# Number of Residential Building Consents                    0.811613
# Population Estimate 15-39                                  0.809180
# Average Accommodation                                      0.807544
# Median Weekly Earnings 20-29                               0.765507
# Approved Student Visa                                      0.606491
# Lodged bonds by territorial authority                      0.211375
# Lodged bonds by region                                    -0.000430
# Student Enrolments by Region                              -0.071621
# Mortgage Floating rate                                    -0.406920
# CPI                                                       -0.475393
# Mortgage 2 year fixed rate                                -0.661959
# Name: Geometric mean rents by territorial authority, dtype: float64

# %% [markdown]
# ### 2.4 Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
attributes = ["Geometric mean rents by territorial authority",
#               "Synthetic lower quartile rents by territorial authority", 
#               "Synthetic lower quartile rents by region", 
#               "Geometric mean rents by region", 
              "Regional GDP",
             "Number of Residential Building Consents",
#              "Lodged bonds by region",
              "Student Enrolments by Region",
              "Lodged bonds by territorial authority"
#               "Average Student Allowance",
#               "Average Accommodation",
#               "Population Estimate 15-39",
#               "Approved Work Visa",
#               "Median Weekly Earnings"
             ]
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Regional GDP", alpha=0.5)

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Student Enrolments by Region", alpha=0.5)

# %%
## Highest correlating geature to geometric mean rents by territorial authority
df.plot(kind="scatter", x="Geometric mean rents by territorial authority", y="Lodged bonds by territorial authority", alpha=0.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

sns.catplot(x="Geometric mean rents by region", y="Region", jitter=False, data=df);

# %%
#order by max
sns.catplot(x="Geometric mean rents by region", y="Region", 
            order=['Auckland','Wellington','Otago', 'Bay of Plenty','Canterbury',
                   'Tasman','Nelson','Hawke\'s Bay','Northland','Waikato'],
            jitter=False, data=df);

# %%
sns.catplot(x="Geometric mean rents by region", y="Region", kind="violin", 
            order=['Auckland','Wellington', 'Canterbury', 'Tasman',
                   'Nelson','Bay of Plenty', 'Otago','Marlborough',
                   'Waikato','Hawke\'s Bay',],
            data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# regions = df['Region']
# for region in regions:
# region_df = df[df['Region']=='Wellington']
sns.catplot(x="Geometric mean rents by territorial authority", y="Territorial Authority",
               orient="h", height=5, aspect=2, kind="swarm", data=region_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-359-843ab67d0d92> in <module>()
#       3 # region_df = df[df['Region']=='Wellington']
#       4 sns.catplot(x="Geometric mean rents by territorial authority", y="Territorial Authority",
# ----> 5                orient="h", height=5, aspect=2, kind="swarm", data=region_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3722     # so we need to define ``palette`` to get default behavior for the
#    3723     # categorical functions
# -> 3724     p.establish_colors(color, palette, 1)
#    3725     if kind != "point" or hue is not None:
#    3726         palette = p.colors
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_colors(self, color, palette, saturation)
#     313         # Determine the gray color to use for the lines framing the plot
#     314         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 315         lum = min(light_vals) * .6
#     316         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     317
#
# ValueError: min() arg is an empty sequence

# %% [markdown]
# ## 3. Data Preparation - Model and Feature Selection

# %% [markdown]
# ### 3.1 Data Transformation

# %%
## Deleting Date of format DateTime as we need int and float objects for regression
import datetime as dt
df['Date']=df['Date'].map(dt.datetime.toordinal)

# Converting categorical values of region and territorial authority to numeric using label encoder
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = df.select_dtypes(include=['object']).apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    df[i] = d[i].transform(df[i].fillna('NA'))
df.head()
# Out:
#      Date  Region  Territorial Authority  Geometric mean rents by region  \
# 0  733102       0                      0                             347
# 1  733102       0                      1                             347
# 2  733102       0                      2                             347
# 3  733102       0                      3                             347
# 4  733102       0                      4                             347
#
#    Geometric mean rents by territorial authority  \
# 0                                            356
# 1                                            294
# 2                                            345
# 3                                            344
# 4                                            323
#
#    Synthetic lower quartile rents by region  \
# 0                                       273
# 1                                       273
# 2                                       273
# 3                                       273
# 4                                       273
#
#    Synthetic lower quartile rents by territorial authority  \
# 0                                                277
# 1                                                250
# 2                                                288
# 3                                                253
# 4                                                265
#
#    Lodged bonds by region  Lodged bonds by territorial authority  \
# 0                    4950                                   2477
# 1                    4950                                    136
# 2                    4950                                    722
# 3                    4950                                    792
# 4                    4950                                    118
#
#    Regional GDP             ...              Median Weekly Earnings 20-29  \
# 0         64644             ...                                     594.5
# 1         64644             ...                                     594.5
# 2         64644             ...                                     594.5
# 3         64644             ...                                     594.5
# 4         64644             ...                                     594.5
#
#    Number of Residential Building Consents  Student Enrolments by Region  \
# 0                                     7999                         90620
# 1                                     7999                         90620
# 2                                     7999                         90620
# 3                                     7999                         90620
# 4                                     7999                         90620
#
#    Approved Student Visa  Approved Work Visa  Average Student Allowance  \
# 0                95355.0            177353.0                     5636.0
# 1                95355.0            177353.0                     5636.0
# 2                95355.0            177353.0                     5636.0
# 3                95355.0            177353.0                     5636.0
# 4                95355.0            177353.0                     5636.0
#
#    Average Accommodation  CPI  Mortgage Floating rate  \
# 0                 1140.0  3.4                    10.4
# 1                 1140.0  3.4                    10.4
# 2                 1140.0  3.4                    10.4
# 3                 1140.0  3.4                    10.4
# 4                 1140.0  3.4                    10.4
#
#    Mortgage 2 year fixed rate
# 0                         9.5
# 1                         9.5
# 2                         9.5
# 3                         9.5
# 4                         9.5
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 3.2 Eliminating Multi-collinearity

# %%
from feature_selector import FeatureSelector
fs=FeatureSelector(df)
fs.identify_collinear(correlation_threshold = 0.90)
fs.plot_collinear()
# Out:
# No labels provided. Feature importance based methods are not available.
# 9 features with a correlation magnitude greater than 0.90.

# %%
# list of collinear features to remove
collinear_features = fs.ops['collinear']

# dataframe of collinear features
fs.record_collinear
# Out:
#                                          drop_feature  \
# 0                      Geometric mean rents by region
# 1            Synthetic lower quartile rents by region
# 2            Synthetic lower quartile rents by region
# 3   Synthetic lower quartile rents by territorial ...
# 4   Synthetic lower quartile rents by territorial ...
# 5   Synthetic lower quartile rents by territorial ...
# 6                                        Regional GDP
# 7                                        Regional GDP
# 8                                        Regional GDP
# 9                           Population Estimate 15-39
# 10                          Population Estimate 15-39
# 11            Number of Residential Building Consents
# 12            Number of Residential Building Consents
# 13                                 Approved Work Visa
# 14                                 Approved Work Visa
# 15                                 Approved Work Visa
# 16                                 Approved Work Visa
# 17                          Average Student Allowance
# 18                          Average Student Allowance
# 19                          Average Student Allowance
# 20                          Average Student Allowance
# 21                              Average Accommodation
# 22                              Average Accommodation
# 23                              Average Accommodation
# 24                              Average Accommodation
#
#                                      corr_feature  corr_value
# 0                                            Date    0.988288
# 1                                            Date    0.983583
# 2                  Geometric mean rents by region    0.998043
# 3                  Geometric mean rents by region    0.900719
# 4   Geometric mean rents by territorial authority    0.975066
# 5        Synthetic lower quartile rents by region    0.900439
# 6                                            Date    1.000000
# 7                  Geometric mean rents by region    0.988278
# 8        Synthetic lower quartile rents by region    0.983554
# 9                  Geometric mean rents by region    0.908660
# 10       Synthetic lower quartile rents by region    0.901616
# 11                 Geometric mean rents by region    0.926244
# 12       Synthetic lower quartile rents by region    0.934271
# 13                 Geometric mean rents by region    0.925345
# 14       Synthetic lower quartile rents by region    0.927132
# 15                      Population Estimate 15-39    0.941150
# 16        Number of Residential Building Consents    0.937215
# 17                                           Date    0.936551
# 18                 Geometric mean rents by region    0.927567
# 19       Synthetic lower quartile rents by region    0.915929
# 20                                   Regional GDP    0.936550
# 21                 Geometric mean rents by region    0.914425
# 22       Synthetic lower quartile rents by region    0.903396
# 23                      Population Estimate 15-39    0.952538
# 24                      Average Student Allowance    0.976636

# %%
df.drop('Synthetic lower quartile rents by territorial authority',axis=1,inplace=True)
df.drop('Synthetic lower quartile rents by region',axis=1,inplace=True)
df.drop('Geometric mean rents by region',axis=1,inplace=True)
df.drop('Lodged bonds by region',axis=1,inplace=True)

df.drop('Approved Work Visa',axis=1,inplace=True)
df.drop('Average Student Allowance',axis=1,inplace=True)
df.drop('Average Accommodation',axis=1,inplace=True)

fs=FeatureSelector(df)
fs.identify_collinear(correlation_threshold = 0.90)

# list of collinear features to remove
collinear_features = fs.ops['collinear']

# dataframe of collinear features
fs.record_collinear
fs.plot_collinear(plot_all = True)
# Out:
# No labels provided. Feature importance based methods are not available.
# 1 features with a correlation magnitude greater than 0.90.

# %% [markdown]
# ### 3.2 Model Selection

# %%
## Choosing Geometric mean as target as less affected by outliers compared to arithemtic mean 
df['target'] = df['Geometric mean rents by territorial authority']
df.drop('Geometric mean rents by territorial authority',axis=1,inplace=True)

features = df[df.columns.difference(df['target'])]
labels = df['target']
features.drop('target',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
print(features.shape, ' ',labels.shape)
# Out:
# (294, 13)   (294,)

# %% [markdown]
# ### 3.3 Feature Selection

# %%
fs=FeatureSelector(data=features, labels=labels)
fs.identify_zero_importance(task = 'regression', 
                            eval_metric = 'auc', 
                            n_iterations = 30, 
                             early_stopping = True)

# list of zero importance features
fs.ops['zero_importance']
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
# 5 features with zero importance after one-hot encoding.
# ['Mortgage 2 year fixed rate',
#  'Population Estimate 15-39',
#  'Region',
#  'Regional GDP',
#  'Student Enrolments by Region']

# %%
# fs.identify_low_importance(cumulative_importance = 0.99)
# fs.ops['low_importance']

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 7 features required for 0.99 of cumulative importance

# %%
fs.feature_importances
# Out:
#                                     feature  importance  \
# 0     Lodged bonds by territorial authority    4.000000
# 1                                      Date    2.566667
# 2                     Approved Student Visa    1.200000
# 3                     Territorial Authority    0.600000
# 4   Number of Residential Building Consents    0.166667
# 5              Median Weekly Earnings 20-29    0.133333
# 6                                       CPI    0.066667
# 7                    Mortgage Floating rate    0.033333
# 8                Mortgage 2 year fixed rate    0.000000
# 9                 Population Estimate 15-39    0.000000
# 10                                   Region    0.000000
# 11                             Regional GDP    0.000000
# 12             Student Enrolments by Region    0.000000
#
#     normalized_importance  cumulative_importance
# 0                0.456274               0.456274
# 1                0.292776               0.749049
# 2                0.136882               0.885932
# 3                0.068441               0.954373
# 4                0.019011               0.973384
# 5                0.015209               0.988593
# 6                0.007605               0.996198
# 7                0.003802               1.000000
# 8                0.000000               1.000000
# 9                0.000000               1.000000
# 10               0.000000               1.000000
# 11               0.000000               1.000000
# 12               0.000000               1.000000

# %%
features = fs.remove(methods='all',keep_one_hot=False)
# Out:
# ['zero_importance'] methods have been run
#
# Removed 5 features including one-hot features.

# %%
features.head()
# Out:
#    Approved Student Visa  CPI    Date  Lodged bonds by territorial authority  \
# 0                95355.0  3.4  733102                                   2477
# 1                95355.0  3.4  733102                                    136
# 2                95355.0  3.4  733102                                    722
# 3                95355.0  3.4  733102                                    792
# 4                95355.0  3.4  733102                                    118
#
#    Median Weekly Earnings 20-29  Mortgage Floating rate  \
# 0                         594.5                    10.4
# 1                         594.5                    10.4
# 2                         594.5                    10.4
# 3                         594.5                    10.4
# 4                         594.5                    10.4
#
#    Number of Residential Building Consents  Territorial Authority
# 0                                     7999                      0
# 1                                     7999                      1
# 2                                     7999                      2
# 3                                     7999                      3
# 4                                     7999                      4

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### 4.1 Before and After Collinearity

# %%
# df_bf_collinear = pd.read_excel(fname+'.xlsx', parse_dates=['Date'], dayfirst=True)

# #remove other target variables
# df_bf_collinear['target'] = df_bf_collinear['Geometric mean rents by territorial authority']
# df_bf_collinear.drop('Geometric mean rents by territorial authority',axis=1,inplace=True)
# df_bf_collinear.drop('Synthetic lower quartile rents by territorial authority',axis=1,inplace=True)
# df_bf_collinear.drop('Synthetic lower quartile rents by region',axis=1,inplace=True)
# df_bf_collinear.drop('Geometric mean rents by region',axis=1,inplace=True)

# #remove highly correlated vars 
# df_bf_collinear.drop('Lodged bonds by region',axis=1,inplace=True)
# df_bf_collinear.drop('Approved Work Visa',axis=1,inplace=True)
# df_bf_collinear.drop('Average Student Allowance',axis=1,inplace=True)
# df_bf_collinear.drop('Average Accommodation',axis=1,inplace=True)

# #
# df_bf_collinear['Date']=df_bf_collinear['Date'].map(dt.datetime.toordinal)
# fit = df_bf_collinear.select_dtypes(include=['object']).apply(lambda x: d[x.name].fit_transform(x))
# for i in list(d.keys()):
#     df_bf_collinear[i] = d[i].transform(df_bf_collinear[i].fillna('NA'))
# df_bf_collinear.head()

# features = df_bf_collinear[df_bf_collinear.columns.difference(df_bf_collinear['target'])]
# features.drop('target',axis=1,inplace=True)
# df_bf_collinear.head()

# %% [markdown]
# ### 4.2 Gradient Boosting Regression Model

# %%
from sklearn.cross_validation import train_test_split

final_vars = list(features) + ['target']
df1 = df[final_vars]
df1.head()

df['Date']=df['Date'].map(dt.datetime.fromordinal)
# train, test = train_test_split(df1, test_size = 0.4)
train = df[df['Date'].dt.year <= 2016]
test = df[df['Date'].dt.year > 2016]

train['Date']=train['Date'].map(dt.datetime.toordinal)
test['Date']=test['Date'].map(dt.datetime.toordinal)

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

X_train  = train[list(features)]
y_train  = train['target']
X_test = test[list(features)]
y_test  = test['target']

# %% [markdown]
# #### 4.2.1 Gradient Boosting - Hyperparameter Tuning

# %%
from sklearn import cross_validation, metrics   
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

gb = GradientBoostingRegressor()

gf_tune = GridSearchCV(estimator = gb, param_grid = grid, cv = 2, verbose=2, n_jobs = -1)
gf_tune.fit(X_train, y_train)

print(gf_tune.best_params_)
# Out:
# Fitting 2 folds for each of 360 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed:    8.0s
# {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 336}
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:    9.5s finished

# %% [markdown]
# #### 4.2.2 Model

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.learning_curve import learning_curve
import time
start_time = time.time()

model = GradientBoostingRegressor(**gf_tune.best_params_)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
model_mse = mean_squared_error(y_pred, y_test)
model_rmse = np.sqrt(model_mse)
print('Gradient Boosting R squared: %.4f' % model.score(X_test, y_test))
print('Gradient Boosting RMSE: %.4f' % model_rmse)
# Out:
# Gradient Boosting R squared: 0.9551
# Gradient Boosting RMSE: 12.8024

# %% [markdown]
# #### 4.2.3 Evaluating Feature Importance

# %%
feature_labels = list(features)
feature_importance = model.feature_importances_

feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.asarray(feature_labels)[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

feature_indexes_by_importance = feature_importance.argsort()
for index in reversed(feature_indexes_by_importance):
    print('{}-{:.2f}%'.format(feature_labels[index], (feature_importance[index])))
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Lodged bonds by territorial authority-100.00%
# Territorial Authority-62.63%
# Date-27.03%
# Approved Student Visa-26.39%
# Number of Residential Building Consents-25.52%
# Median Weekly Earnings 20-29-21.39%
# CPI-20.80%
# Mortgage Floating rate-15.63%
# --- 0.17571711540222168 seconds ---

# %% [markdown]
# #### 4.2.4 Learning Curve

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.
        
    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

plot_learning_curve(model, "Learning curve", X_train, y_train, cv=10, n_jobs=3) 
plt.show()
